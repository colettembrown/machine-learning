# %% [markdown]
# serial_num = [M98, M508, M727, M520, K85, K58, K13, K7, K74, K75, K64, F225, F292, F241, F453, F464, F165, F182, F334, F88]
#
# M:[1-100:98][500-600:520][700-800:727]
# K:[1-100:85]
# F:[1-100:88][100-200:182][200-300:292][300-400:334][400-500:464]
#
#
# Derive the maximum likelihood formula for the total number of tanks given a dataset as above.
#
# Use the formula that you derived in the previous question to estimate how many tanks there are given the dataset in the description.
#
# How strongly do you believe your estimate?

# %% [markdown]
# P(observing X1 | data) = P(L,N | serial_num)

# %% [markdown]
# Write out the likelihood of observing a single tank.
#
# N: Total number of tanks
#
# L: Letter on tank
# Nu: Number on tank
# T: total number of tanks
# serial_num = [M98, M508, M520, M727, K7, K13, K 58, K64, K74, K75, K85, F88, F165, F182, F225, F241, F292, F334, F453, F464]
# P(M_total_trains | M_data) + P(K_total_trains | K_data) + P(F_total_trains | F_data) =

# %% [markdown]
# Derive the maximum likelihood formula for the total number of tanks given a dataset as above.

# %% [markdown]
# For EM purposes, it is useful to define the following indicator function: $\ I(x,i) = 1 $, when x belongs to cluster i, and 0 otherwise . This allows one to specify the likelihood for a single data point as:
#
# $$ L(x) = \prod_i P(C=i)^I(x,i) P(x | C=i)^I(x,i) $$
